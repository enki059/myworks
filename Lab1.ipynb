# %% [markdown]
# <a href="https://colab.research.google.com/github/enki059/myworks/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Тема 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2025-03-19 213443.png](data:image/png;base64,...)

# %%
# 1)
x = float(input("x = "))
y = float(input("y = "))
z = (-20*y)/3
print(f"z = {z}")
# Out:
# x = 13
# y = 15
# z = -100.0, z1 = -100.0

# %%
# 2)
from math import tan
a = float(input("a = "))
b = float(input("b = "))
c = tan(a)
print(f"c = {c}")
